# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulSalamKagaji97/AbdulSalamKagaji_DATA606/blob/main/src/Capstone_Project_Abdul_Salam_Kagaji.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')

import seaborn as sns
color = sns.color_palette()
sns.set(rc={'figure.figsize':(25,15)})

import plotly as px
# plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go

import plotly.figure_factory as ff
import cufflinks as cf


import warnings
warnings.filterwarnings('ignore')

# %%
appDf = pd.read_csv('https://raw.githubusercontent.com/abdulSalamKagaji97/AbdulSalamKagaji_DATA606/main/data/apps.csv')
appDescDf = pd.read_csv('https://raw.githubusercontent.com/abdulSalamKagaji97/AbdulSalamKagaji_DATA606/main/data/AppDescriptions.csv')

mergeDf = appDf.merge(appDescDf,on="App")
mergeDf
#print(len(df))
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 2              1                                Coloring book moana
# 3              1                                Coloring book moana
# 4              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# ...          ...                                                ...
# 9786       10836                                   Sya9a Maroc - FR
# 9787       10837                   Fr. Mike Schmitz Audio Teachings
# 9788       10838                             Parkinson Exercices FR
# 9789       10839                      The SCP Foundation DB fr nn5n
# 9790       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews  Size     Installs  Type Price  \
# 0          ART_AND_DESIGN     4.1      159  19.0      10,000+  Free     0
# 1          ART_AND_DESIGN     4.1      159  19.0      10,000+  Free     0
# 2          ART_AND_DESIGN     3.9      967  14.0     500,000+  Free     0
# 3          ART_AND_DESIGN     3.9      967  14.0     500,000+  Free     0
# 4          ART_AND_DESIGN     4.7    87510   8.7   5,000,000+  Free     0
# ...                   ...     ...      ...   ...          ...   ...   ...
# 9786               FAMILY     4.5       38  53.0       5,000+  Free     0
# 9787               FAMILY     5.0        4   3.6         100+  Free     0
# 9788              MEDICAL     NaN        3   9.5       1,000+  Free     0
# 9789  BOOKS_AND_REFERENCE     4.5      114   NaN       1,000+  Free     0
# 9790            LIFESTYLE     4.5   398307  19.0  10,000,000+  Free     0
#
#      Content Rating                     Genres      Last Updated  \
# 0          Everyone               Art & Design   January 7, 2018
# 1          Everyone               Art & Design   January 7, 2018
# 2          Everyone  Art & Design;Pretend Play  January 15, 2018
# 3          Everyone  Art & Design;Pretend Play  January 15, 2018
# 4          Everyone               Art & Design    August 1, 2018
# ...             ...                        ...               ...
# 9786       Everyone                  Education     July 25, 2017
# 9787       Everyone                  Education      July 6, 2018
# 9788       Everyone                    Medical  January 20, 2017
# 9789     Mature 17+          Books & Reference  January 19, 2015
# 9790       Everyone                  Lifestyle     July 25, 2018
#
#              Current Ver         Android Ver  \
# 0                  1.0.0        4.0.3 and up
# 1                  1.0.0        4.0.3 and up
# 2                  2.0.0        4.0.3 and up
# 3                  2.0.0        4.0.3 and up
# 4                  1.2.4        4.0.3 and up
# ...                  ...                 ...
# 9786                1.48          4.1 and up
# 9787                   1          4.1 and up
# 9788                   1          2.2 and up
# 9789  Varies with device  Varies with device
# 9790  Varies with device  Varies with device
#
#                                            Descriptions
# 0     Filters for photos and videos Beautification t...
# 1     Filters for photos and videos Beautification t...
# 2     Welcome this app for Coloring Book Encanto Car...
# 3     Welcome this app for Coloring Book Encanto Car...
# 4         Android themes & 4D Live wallpaper, Hide apps
# ...                                                 ...
# 9786  Moroccan driving licence tests en français and...
# 9787  Download and Listen Fr. Mike Schmitz Audio Mes...
# 9788  Home Exercises for people with Parkinson's dis...
# 9789  SCP Foundation: Idle Manager is a game that si...
# 9790  Daily Horoscope - the most popular horoscope a...
#
# [9791 rows x 15 columns]

# %%
mergeDf.columns
# Out:
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver', 'Descriptions'],
#       dtype='object')

# %%
mergeDf = mergeDf[[ 'App', 'Descriptions', 'Category', 'Rating', 'Reviews', 'Size',
       'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
       'Current Ver', 'Android Ver']]
mergeDf
# Out:
#                                                     App  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1        Photo Editor & Candy Camera & Grid & ScrapBook
# 2                                   Coloring book moana
# 3                                   Coloring book moana
# 4     U Launcher Lite – FREE Live Cool Themes, Hide ...
# ...                                                 ...
# 9786                                   Sya9a Maroc - FR
# 9787                   Fr. Mike Schmitz Audio Teachings
# 9788                             Parkinson Exercices FR
# 9789                      The SCP Foundation DB fr nn5n
# 9790      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                                            Descriptions             Category  \
# 0     Filters for photos and videos Beautification t...       ART_AND_DESIGN
# 1     Filters for photos and videos Beautification t...       ART_AND_DESIGN
# 2     Welcome this app for Coloring Book Encanto Car...       ART_AND_DESIGN
# 3     Welcome this app for Coloring Book Encanto Car...       ART_AND_DESIGN
# 4         Android themes & 4D Live wallpaper, Hide apps       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9786  Moroccan driving licence tests en français and...               FAMILY
# 9787  Download and Listen Fr. Mike Schmitz Audio Mes...               FAMILY
# 9788  Home Exercises for people with Parkinson's dis...              MEDICAL
# 9789  SCP Foundation: Idle Manager is a game that si...  BOOKS_AND_REFERENCE
# 9790  Daily Horoscope - the most popular horoscope a...            LIFESTYLE
#
#       Rating  Reviews  Size     Installs  Type Price Content Rating  \
# 0        4.1      159  19.0      10,000+  Free     0       Everyone
# 1        4.1      159  19.0      10,000+  Free     0       Everyone
# 2        3.9      967  14.0     500,000+  Free     0       Everyone
# 3        3.9      967  14.0     500,000+  Free     0       Everyone
# 4        4.7    87510   8.7   5,000,000+  Free     0       Everyone
# ...      ...      ...   ...          ...   ...   ...            ...
# 9786     4.5       38  53.0       5,000+  Free     0       Everyone
# 9787     5.0        4   3.6         100+  Free     0       Everyone
# 9788     NaN        3   9.5       1,000+  Free     0       Everyone
# 9789     4.5      114   NaN       1,000+  Free     0     Mature 17+
# 9790     4.5   398307  19.0  10,000,000+  Free     0       Everyone
#
#                          Genres      Last Updated         Current Ver  \
# 0                  Art & Design   January 7, 2018               1.0.0
# 1                  Art & Design   January 7, 2018               1.0.0
# 2     Art & Design;Pretend Play  January 15, 2018               2.0.0
# 3     Art & Design;Pretend Play  January 15, 2018               2.0.0
# 4                  Art & Design    August 1, 2018               1.2.4
# ...                         ...               ...                 ...
# 9786                  Education     July 25, 2017                1.48
# 9787                  Education      July 6, 2018                   1
# 9788                    Medical  January 20, 2017                   1
# 9789          Books & Reference  January 19, 2015  Varies with device
# 9790                  Lifestyle     July 25, 2018  Varies with device
#
#              Android Ver
# 0           4.0.3 and up
# 1           4.0.3 and up
# 2           4.0.3 and up
# 3           4.0.3 and up
# 4           4.0.3 and up
# ...                  ...
# 9786          4.1 and up
# 9787          4.1 and up
# 9788          2.2 and up
# 9789  Varies with device
# 9790  Varies with device
#
# [9791 rows x 14 columns]
